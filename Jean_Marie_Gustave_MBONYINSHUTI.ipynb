# %% [markdown]
# <a href="https://colab.research.google.com/github/GustaveRw/NLP-Fellowship/blob/master/Jean_Marie_Gustave_MBONYINSHUTI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data collection:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
vw_df = pd.read_excel('/content/Data Analyst Interview exam.xlsx')

# %%
vw_df.head(15)
# Out:
#    Plate_Number  Final_Price         Date     status              Driver_Name  \
# 0     RAE 172 A         8450  07-Dec-2022  COMPLETED      Martin MUNYABUGINGO
# 1     RAE 162 A         3200  07-Dec-2022  COMPLETED             Mugisha Grey
# 2     RAE 785 B         3600  07-Dec-2022  COMPLETED           NIZEYIMANA JMV
# 3    RAE  232 A         2600  07-Dec-2022  COMPLETED     Rudakorerwa Emmanuel
# 4     RAE 788 B         4300  07-Dec-2022  COMPLETED          Moses BAYINGANA
# 5     RAD 268 Z         7750  07-Dec-2022  COMPLETED         Kaaaabayiza Jean
# 6     RAD 281 Z         9150  07-Dec-2022  COMPLETED       Ally Kevin Mugisha
# 7     RAE 167 A        10000  07-Dec-2022  COMPLETED          Steven Ruzibiza
# 8     RAE 167 A         6850  07-Dec-2022  COMPLETED          Steven Ruzibiza
# 9     RAE 162 A         2500  07-Dec-2022  COMPLETED  Mutimura Jean Damascene
# 10    RAE 162 A         2400  07-Dec-2022  COMPLETED  Mutimura Jean Damascene
# ...

# %%
vw_df.tail(10)
# Out:
#     Plate_Number  Final_Price         Date     status  \
# 200    RAD 276 z         4800  01-Dec-2022  COMPLETED
# 201    RAE 630 C         7450  01-Dec-2022  COMPLETED
# 202    RAD 286 Z         8950  01-Dec-2022  COMPLETED
# 203    RAD 319 Z         3200  01-Dec-2022  COMPLETED
# 204    RAD 276 z         5900  01-Dec-2022  COMPLETED
# 205    RAE 631 C        13600  01-Dec-2022  COMPLETED
# 206    RAE 630 C         6100  01-Dec-2022  COMPLETED
# 207    RAE 628 C         6550  01-Dec-2022  COMPLETED
# 208    RAE 229 A         5850  01-Dec-2022  COMPLETED
# 209    RAD 321 Z         9550  01-Dec-2022  COMPLETED
#
#                      Driver_Name              Client_Name  \
# 200            Philbert Murashii        James Nyirinkwaya
# 201                 Deo Kabirigi             Rhodah Njagi
# 202                Vital Ndahayo      Jackson  Zimurinda
# 203  Jean Baptistee MBARUSHIMANA          fraizer fraizer
# 204            Philbert Murashii  Sharonyyyyy Mutoniyyyyy
# ...

# %%
vw_df.shape
# Out:
# (210, 8)

# %%
vw_df.size
# Out:
# 1680

# %%
vw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Plate_Number               210 non-null    object
#  1   Final_Price                210 non-null    int64
#  2   Date                       210 non-null    object
#  3   status                     210 non-null    object
#  4   Driver_Name                210 non-null    object
#  5   Client_Name                210 non-null    object
#  6   Final_Trip_Time (Minutes)  210 non-null    int64
#  7   Final_Trip_Distance (KM)   210 non-null    float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 13.2+ KB

# %% [markdown]
# ## Data cleaning and preprocessing:

# %%
vw_df.isnull().values.any()
# Out:
# False

# %%
vw_df.describe()
# Out:
#         Final_Price  Final_Trip_Time (Minutes)  Final_Trip_Distance (KM)
# count    210.000000                 210.000000                210.000000
# mean    7696.666667                  25.180952                  7.329714
# std     6225.152586                  31.519351                  6.142121
# min      600.000000                   0.000000                  0.000000
# 25%     4250.000000                  11.000000                  2.930000
# 50%     6550.000000                  19.000000                  6.845000
# 75%     9125.000000                  28.000000                  9.777500
# max    57900.000000                 304.000000                 40.420000

# %% [markdown]
# ## Data exploration and visualization

# %%
vw_df.plot(kind='line', x='Final_Price', y='Final_Trip_Time (Minutes)', figsize=(25,10))
plt.show()

# %%
vw_df.plot(kind='line', x='Final_Price', y='Final_Trip_Distance (KM)', figsize=(25,10), color='black')

plt.show()

# %%
vw_df.plot(kind='line', x='Date', y='Final_Trip_Distance (KM)', figsize=(25,10), color='green')

plt.show()

# %%
vw_df.plot(kind='line', x='Date', y='Final_Trip_Time (Minutes)', figsize=(25,10), color='red')

plt.show()

# %%
print(np.array(vw_df['Driver_Name'].dropna().unique()))
vw_df['Final_Trip_Distance (KM)'].groupby(vw_df['Driver_Name']).sum()

# %%
print(np.array(vw_df['Driver_Name'].dropna().unique()))
vw_df['Final_Trip_Time (Minutes)'].groupby(vw_df['Driver_Name']).sum()

# %%
df = pd.DataFrame(vw_df['Final_Trip_Distance (KM)'].groupby(vw_df['Driver_Name']).sum())
df.plot(kind = 'bar', figsize=(25,10))
plt.show()

# %%
df = pd.DataFrame(vw_df['Final_Trip_Time (Minutes)'].groupby(vw_df['Driver_Name']).sum())
df.plot(kind = 'bar', figsize=(25,10), color='brown')
plt.show()

# %%
sns.pairplot(vw_df)
