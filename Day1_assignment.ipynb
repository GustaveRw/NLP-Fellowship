# %% [markdown]
# <a href="https://colab.research.google.com/github/GustaveRw/NLP-Fellowship/blob/master/Day1_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

response = requests.get("https://dummyjson.com/products")
products = json.loads(response.text)

print(len(products))
print(response.json())
# Out:
# 4
# ...

# %%
import pandas as pd
import requests

response = requests.get("https://dummyjson.com/products")

json = response.json()

df = pd.DataFrame(json['products'])

df.tail(20)
# Out:
#     id                                   title  \
# 10  11                             perfume Oil
# 11  12                           Brown Perfume
# 12  13              Fog Scent Xpressio Perfume
# 13  14  Non-Alcoholic Concentrated Perfume Oil
# 14  15                    Eau De Perfume Spray
# 15  16                   Hyaluronic Acid Serum
# 16  17                           Tree Oil 30ml
# 17  18              Oil Free Moisturizer 100ml
# 18  19                      Skin Beauty Serum.
# 19  20           Freckle Treatment Cream- 15gm
# 20  21                 - Daal Masoor 500 grams
# 21  22                 Elbow Macaroni - 400 gm
# 22  23              Orange Essence Food Flavou
# 23  24               cereals muesli fruit nuts
# 24  25                    Gulab Powder 50 Gram
# 25  26                   Plant Hanger For Home
# 26  27                      Flying Wooden Bird
# 27  28               3D Embellishment Art Lamp
# 28  29                 Handcraft Chinese style
# ...

# %%
import json

data = {
    "products":{
        "category",
        "brand",
        "list of products",
        "average price"
    }
}

print(data)
# Out:
# {'products': {'list of products', 'category', 'brand', 'average price'}}
