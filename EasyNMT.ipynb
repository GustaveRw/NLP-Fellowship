# %% [markdown]
# <a href="https://colab.research.google.com/github/GustaveRw/NLP-Fellowship/blob/master/EasyNMT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U easynmt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 19.2 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 53.8 MB/s
# ...
#      |████████████████████████████████| 68 kB 7.8 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 47.8 MB/s
# ...
#      |████████████████████████████████| 163 kB 69.2 MB/s
# ...
#   Using cached pybind11-2.10.1-py3-none-any.whl (216 kB)
# ...
#   Created wheel for easynmt: filename=EasyNMT-2.0.2-py3-none-any.whl size=19919 sha256=8853fd776860bca94c118622f120c77e2446a85104edbdfb2029a5681ab273b7
#   Stored in directory: /root/.cache/pip/wheels/d1/57/06/53ca38645e14d4537a41e5a36da2026e10f54ae88240dd5190
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3163311 sha256=200598d223a6a9829b8d4f146fa16bc47e7cae3d30c4114453a8cbbcf8fb5b69
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
# ...

# %%
from easynmt import EasyNMT

# %%
model = EasyNMT('opus-mt')
# Out:
# 11.9kB [00:00, 6.41MB/s]

# %%
sentences =  [
    'I love my life.', 'Conversation AI is part of NLP',
    'I met interesting people this month', 'I remember to brush my teeth in the morning',
    'Jesus is alive', 'My mother is my everything'
]

# %%
translations_fr = model.translate(sentences, target_lang='fr')
translations_rw = model.translate(sentences, target_lang='rw')
translations_zh = model.translate(sentences, target_lang='zh')
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# Downloading:   0%|          | 0.00/806k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/805k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Downloading:   0%|          | 0.00/312M [00:00<?, ?B/s]

# %%
translations_rw
# Out:
# ['Nkunda ubuzima.',
#  'ni Bya',
#  "Nahuye n'abantu bashimishijwe muri uko kwezi",
#  'Ndibuka ko mu gitondo nagombaga koza amenyo',
#  'Yesu ni muzima',
#  'Mama ni we bintu byanjye byose']

# %%
translations_zh
# Out:
# ['我爱我的生活。', '大赦国际是国家语言平台的一部分。', '这个月我遇到一些有趣的人', '我记得早上刷牙', '耶稣还活着', '我母亲是我的一切']
