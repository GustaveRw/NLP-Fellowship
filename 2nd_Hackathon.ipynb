# %% [markdown]
# <a href="https://colab.research.google.com/github/GustaveRw/NLP-Fellowship/blob/master/2nd_Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web Scrapping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#Fetch the content from the front page
content = requests.get('https://rura.rw/index.php').content

# %%
#Preview of the Content
content

# %%
#Initiating the BS4 parser
page = BeautifulSoup(content, 'html.parser')

# %%
#Get all the links in the website
links = page.find_all('a')

# %%
links

# %%
#Drop the first link because it's not related
del links[0]

# %%
index = -30
link = links[index]['href'] #Get the link
title = links[index].text #Save the description
print('Link:', link, 'Described as:', title)
# Out:
# Link: index.php?id=46 Described as: RURA Mission, Vision and Values

# %%
list_of_links = [] #list()
list_of_titles = []

for item in links: #loop over the list of links
  if str(item['href'])[0:9] == 'index.php':
    lin = 'https://rura.rw/' + item['href']
  else:
    lin = item['href']

  list_of_links.append(lin)
  if len(item.text) > 0:
    list_of_titles.append(item.text)
  else:
    list_of_titles.append(None)

# %%
df = pd.DataFrame()
df['title'] = list_of_titles
df['link'] = list_of_links
df['description'] = None

# %%
list_of_links

# %%
#Preview the dataframe
df.describe()
# Out:
#            title                             link description
# count        169                              175           0
# unique        98                              132           0
# top     Overview  https://rura.rw/index.php?id=89         NaN
# freq          10                                3         NaN

# %%
#Drop all the row with empty title columns
df = df.dropna(subset=['title'])

# %%
df
# Out:
#                                           title  \
# 0    business plan to buy an apartment building
# 1    writing a good abstract for research paper
# 2                        statement of admission
# 9                                          Home
# 10                                   About RURA
# ..                                          ...
# 170                      Regulatory instruments
# 171                             Sector  Reports
# 172                                  Statistics
# 173                                        FAQs
# 174                         All Online Services
#
#                                                   link description
# 0    http://rura.rw/?business-plan-to-buy-an-apartm...        None
# 1    http://rura.rw/?writing-a-good-abstract-for-re...        None
# 2               http://rura.rw/?statement-of-admission        None
# 9                      https://rura.rw/index.php?id=23        None
# 10                     https://rura.rw/index.php?id=25        None
# ..                                                 ...         ...
# 170                   https://rura.rw/index.php?id=179        None
# 171                   https://rura.rw/index.php?id=185        None
# 172                    https://rura.rw/index.php?id=86        None
# 173                    https://rura.rw/index.php?id=88        None
# 174                         https://licensing.rura.rw/        None
#
# [169 rows x 3 columns]

# %%
#Check whehter the link is full formated link
is_full_link = df.link.str.startswith('http')

#Check whether the link is pdf documents
is_pdf = df.link.str.contains('.pdf')

# %%
df['is_full_link'] = is_full_link #Create a new col
df['is_pdf'] = is_pdf #create a new col

# %%
df
# Out:
#                                           title  \
# 0    business plan to buy an apartment building
# 1    writing a good abstract for research paper
# 2                        statement of admission
# 9                                          Home
# 10                                   About RURA
# ..                                          ...
# 170                      Regulatory instruments
# 171                             Sector  Reports
# 172                                  Statistics
# 173                                        FAQs
# 174                         All Online Services
#
#                                                   link description  \
# 0    http://rura.rw/?business-plan-to-buy-an-apartm...        None
# 1    http://rura.rw/?writing-a-good-abstract-for-re...        None
# 2               http://rura.rw/?statement-of-admission        None
# 9                      https://rura.rw/index.php?id=23        None
# 10                     https://rura.rw/index.php?id=25        None
# ..                                                 ...         ...
# 170                   https://rura.rw/index.php?id=179        None
# 171                   https://rura.rw/index.php?id=185        None
# 172                    https://rura.rw/index.php?id=86        None
# 173                    https://rura.rw/index.php?id=88        None
# 174                         https://licensing.rura.rw/        None
#
#      is_full_link  is_pdf
# 0            True   False
# 1            True   False
# 2            True   False
# 9            True   False
# 10           True   False
# ..            ...     ...
# 170          True   False
# 171          True   False
# 172          True   False
# 173          True   False
# 174          True   False
#
# [169 rows x 5 columns]

# %%
df = df[df['is_full_link'] == True ] #Drop all the links
df =  df[df['is_pdf'] == False ]

# %%
df
# Out:
#                                           title  \
# 0    business plan to buy an apartment building
# 1    writing a good abstract for research paper
# 2                        statement of admission
# 9                                          Home
# 10                                   About RURA
# ..                                          ...
# 170                      Regulatory instruments
# 171                             Sector  Reports
# 172                                  Statistics
# 173                                        FAQs
# 174                         All Online Services
#
#                                                   link description  \
# 0    http://rura.rw/?business-plan-to-buy-an-apartm...        None
# 1    http://rura.rw/?writing-a-good-abstract-for-re...        None
# 2               http://rura.rw/?statement-of-admission        None
# 9                      https://rura.rw/index.php?id=23        None
# 10                     https://rura.rw/index.php?id=25        None
# ..                                                 ...         ...
# 170                   https://rura.rw/index.php?id=179        None
# 171                   https://rura.rw/index.php?id=185        None
# 172                    https://rura.rw/index.php?id=86        None
# 173                    https://rura.rw/index.php?id=88        None
# 174                         https://licensing.rura.rw/        None
#
#      is_full_link  is_pdf
# 0            True   False
# 1            True   False
# 2            True   False
# 9            True   False
# 10           True   False
# ..            ...     ...
# 170          True   False
# 171          True   False
# 172          True   False
# 173          True   False
# 174          True   False
#
# [165 rows x 5 columns]

# %%
# import textract as tx

# description = []
# #Get the description of each job

# for index in range(len(df)):
#   try:
#     if df['link'][index].str.endswith('.pdf'):
#       content =  requests.get(df['link'][index]).raw
#       with open(f'test{index}.pdf', 'w+') as file:
#         file.write(content)

#       doc = tx.process(f'test{index}.pdf')

#       df.loc[index]['description'] = doc.text

#     raw_content = requests.get(df['link'][index]).content
#     df.loc[index]['description'] = raw_content.text
#   except :
#     pass

# %%
# description = []
# #Get the description of each job

# for index in range(3):
#   try:
#     raw_content = requests.get(df['link'][index]).content
#     description.append(raw_content.text)
#   except :
#     description.append('')

# df['description'] = description

# %%
df
# Out:
#                                           title  \
# 0    business plan to buy an apartment building
# 1    writing a good abstract for research paper
# 2                        statement of admission
# 9                                          Home
# 10                                   About RURA
# ..                                          ...
# 170                      Regulatory instruments
# 171                             Sector  Reports
# 172                                  Statistics
# 173                                        FAQs
# 174                         All Online Services
#
#                                                   link description  \
# 0    http://rura.rw/?business-plan-to-buy-an-apartm...        None
# 1    http://rura.rw/?writing-a-good-abstract-for-re...        None
# 2               http://rura.rw/?statement-of-admission        None
# 9                      https://rura.rw/index.php?id=23        None
# 10                     https://rura.rw/index.php?id=25        None
# ..                                                 ...         ...
# 170                   https://rura.rw/index.php?id=179        None
# 171                   https://rura.rw/index.php?id=185        None
# 172                    https://rura.rw/index.php?id=86        None
# 173                    https://rura.rw/index.php?id=88        None
# 174                         https://licensing.rura.rw/        None
#
#      is_full_link  is_pdf
# 0            True   False
# 1            True   False
# 2            True   False
# 9            True   False
# 10           True   False
# ..            ...     ...
# 170          True   False
# 171          True   False
# 172          True   False
# 173          True   False
# 174          True   False
#
# [165 rows x 5 columns]

# %%
import re 

def preprocessing(titles : list):
  cleaned_titles = []
  for title in titles:
    title = title.lower()
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    html_pattern = re.compile('<.*?>')
    title = url_pattern.sub(r'', title)
    title = html_pattern.sub(r'', title)
    title = re.sub(r"[^\w\d'\s]+", ' ', title)
    cleaned_titles.append(title)
  return cleaned_titles


df['title'] = preprocessing(df['title'])

# %%
df
# Out:
#                                           title  \
# 0    business plan to buy an apartment building
# 1    writing a good abstract for research paper
# 2                        statement of admission
# 9                                          home
# 10                                   about rura
# ..                                          ...
# 170                      regulatory instruments
# 171                             sector  reports
# 172                                  statistics
# 173                                        faqs
# 174                         all online services
#
#                                                   link description  \
# 0    http://rura.rw/?business-plan-to-buy-an-apartm...        None
# 1    http://rura.rw/?writing-a-good-abstract-for-re...        None
# 2               http://rura.rw/?statement-of-admission        None
# 9                      https://rura.rw/index.php?id=23        None
# 10                     https://rura.rw/index.php?id=25        None
# ..                                                 ...         ...
# 170                   https://rura.rw/index.php?id=179        None
# 171                   https://rura.rw/index.php?id=185        None
# 172                    https://rura.rw/index.php?id=86        None
# 173                    https://rura.rw/index.php?id=88        None
# 174                         https://licensing.rura.rw/        None
#
#      is_full_link  is_pdf
# 0            True   False
# 1            True   False
# 2            True   False
# 9            True   False
# 10           True   False
# ..            ...     ...
# 170          True   False
# 171          True   False
# 172          True   False
# 173          True   False
# 174          True   False
#
# [165 rows x 5 columns]

# %% [markdown]
# # Start Building the chatbot

# %% [markdown]
# ## Building the intent file

# %%
question = """Guide me to {}?
Where do you get {}?
What is the link to the {}?
How do you get {}?
Who is in Charge of {}?"""

answers = """Here is the link {}.
You can use this link {} for more information."""

# %%
question.split('\n')
# Out:
# ['Guide me to {}?',
#  'Where do you get {}?',
#  'What is the link to the {}?',
#  'How do you get {}?',
#  'Who is in Charge of {}?']

# %%
df.iloc[10]
# Out:
# title           Regional and International Partnerships
# link                    https://rura.rw/index.php?id=47
# description                                        None
# is_full_link                                       True
# is_pdf                                            False
# Name: 16, dtype: object

# %%
intents = []

for index in range(len(df)):
  intent = {}
  tag = df.iloc[index]['title']
  intent['tag'] = tag
  intent['patterns'] = list()
  intent['responses'] = [f'You can use this link {df.iloc[index].link} for more information']
  for i in range(len(question.split('\n'))):
    intent['patterns'].append(question.split('\n')[i].format(intent['tag']))

  intents.append(intent)
  
file = {'intents': intents}

# %%
file
# Out:
# {'intents': [{'tag': 'business plan to buy an apartment building',
#    'patterns': ['Guide me to business plan to buy an apartment building?',
#     'Where do you get business plan to buy an apartment building?',
#     'What is the link to the business plan to buy an apartment building?',
#     'How do you get business plan to buy an apartment building?',
#     'Who is in Charge of business plan to buy an apartment building?'],
#    'responses': ['You can use this link http://rura.rw/?business-plan-to-buy-an-apartment-building for more information']},
#   {'tag': 'writing a good abstract for research paper',
#    'patterns': ['Guide me to writing a good abstract for research paper?',
#     'Where do you get writing a good abstract for research paper?',
#     'What is the link to the writing a good abstract for research paper?',
#     'How do you get writing a good abstract for research paper?',
#     'Who is in Charge of writing a good abstract for research paper?'],
#    'responses': ['You can use this link http://rura.rw/?writing-a-good-abstract-for-research-paper for more information']},
#   {'tag': 'statement of admission',
#    'patterns': ['Guide me to statement of admission?',
#     'Where do you get statement of admission?',
#     'What is the link to the statement of admission?',
#     'How do you get statement of admission?',
#     'Who is in Charge of statement of admission?'],
#    'responses': ['You can use this link http://rura.rw/?statement-of-admission for more information']},
#   {'tag': 'home',
#    'patterns': ['Guide me to home?',
#     'Where do you get home?',
#     'What is the link to the home?',
#     'How do you get home?',
#     'Who is in Charge of home?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=23 for more information']},
#   {'tag': 'about rura',
#    'patterns': ['Guide me to about rura?',
#     'Where do you get about rura?',
#     'What is the link to the about rura?',
#     'How do you get about rura?',
#     'Who is in Charge of about rura?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=25 for more information']},
#   {'tag': 'background',
#    'patterns': ['Guide me to background?',
#     'Where do you get background?',
#     'What is the link to the background?',
#     'How do you get background?',
#     'Who is in Charge of background?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=44 for more information']},
#   {'tag': 'rura functions',
#    'patterns': ['Guide me to rura functions?',
#     'Where do you get rura functions?',
#     'What is the link to the rura functions?',
#     'How do you get rura functions?',
#     'Who is in Charge of rura functions?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=45 for more information']},
#   {'tag': 'rura mission  vision and values',
#    'patterns': ['Guide me to rura mission  vision and values?',
#     'Where do you get rura mission  vision and values?',
#     'What is the link to the rura mission  vision and values?',
#     'How do you get rura mission  vision and values?',
#     'Who is in Charge of rura mission  vision and values?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=46 for more information']},
#   {'tag': 'rura law and related orders',
#    'patterns': ['Guide me to rura law and related orders?',
#     'Where do you get rura law and related orders?',
#     'What is the link to the rura law and related orders?',
#     'How do you get rura law and related orders?',
#     'Who is in Charge of rura law and related orders?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=202 for more information']},
#   {'tag': 'regional and international partnerships',
#    'patterns': ['Guide me to regional and international partnerships?',
#     'Where do you get regional and international partnerships?',
#     'What is the link to the regional and international partnerships?',
#     'How do you get regional and international partnerships?',
#     'Who is in Charge of regional and international partnerships?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=47 for more information']},
#   {'tag': 'consumer affairs',
#    'patterns': ['Guide me to consumer affairs?',
#     'Where do you get consumer affairs?',
#     'What is the link to the consumer affairs?',
#     'How do you get consumer affairs?',
#     'Who is in Charge of consumer affairs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=262 for more information']},
#   {'tag': 'overview',
#    'patterns': ['Guide me to overview?',
#     'Where do you get overview?',
#     'What is the link to the overview?',
#     'How do you get overview?',
#     'Who is in Charge of overview?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=263 for more information']},
#   {'tag': 'consumer rights and obligations',
#    'patterns': ['Guide me to consumer rights and obligations?',
#     'Where do you get consumer rights and obligations?',
#     'What is the link to the consumer rights and obligations?',
#     'How do you get consumer rights and obligations?',
#     'Who is in Charge of consumer rights and obligations?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=264 for more information']},
#   {'tag': 'complaints handling procedures',
#    'patterns': ['Guide me to complaints handling procedures?',
#     'Where do you get complaints handling procedures?',
#     'What is the link to the complaints handling procedures?',
#     'How do you get complaints handling procedures?',
#     'Who is in Charge of complaints handling procedures?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=265 for more information']},
#   {'tag': 'consumer awareness and educational tools',
#    'patterns': ['Guide me to consumer awareness and educational tools?',
#     'Where do you get consumer awareness and educational tools?',
#     'What is the link to the consumer awareness and educational tools?',
#     'How do you get consumer awareness and educational tools?',
#     'Who is in Charge of consumer awareness and educational tools?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=266 for more information']},
#   {'tag': 'laws and regulations',
#    'patterns': ['Guide me to laws and regulations?',
#     'Where do you get laws and regulations?',
#     'What is the link to the laws and regulations?',
#     'How do you get laws and regulations?',
#     'Who is in Charge of laws and regulations?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=268 for more information']},
#   {'tag': 'strategic plan 2022 2027',
#    'patterns': ['Guide me to strategic plan 2022 2027?',
#     'Where do you get strategic plan 2022 2027?',
#     'What is the link to the strategic plan 2022 2027?',
#     'How do you get strategic plan 2022 2027?',
#     'Who is in Charge of strategic plan 2022 2027?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=289 for more information']},
#   {'tag': 'service charter',
#    'patterns': ['Guide me to service charter?',
#     'Where do you get service charter?',
#     'What is the link to the service charter?',
#     'How do you get service charter?',
#     'Who is in Charge of service charter?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=150 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=103 for more information']},
#   {'tag': 'ict',
#    'patterns': ['Guide me to ict?',
#     'Where do you get ict?',
#     'What is the link to the ict?',
#     'How do you get ict?',
#     'Who is in Charge of ict?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=48 for more information']},
#   {'tag': 'overview',
#    'patterns': ['Guide me to overview?',
#     'Where do you get overview?',
#     'What is the link to the overview?',
#     'How do you get overview?',
#     'Who is in Charge of overview?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=49 for more information']},
#   {'tag': 'sub sectors and services',
#    'patterns': ['Guide me to sub sectors and services?',
#     'Where do you get sub sectors and services?',
#     'What is the link to the sub sectors and services?',
#     'How do you get sub sectors and services?',
#     'Who is in Charge of sub sectors and services?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=159 for more information']},
#   {'tag': 'ict scarce resources management and monitoring',
#    'patterns': ['Guide me to ict scarce resources management and monitoring?',
#     'Where do you get ict scarce resources management and monitoring?',
#     'What is the link to the ict scarce resources management and monitoring?',
#     'How do you get ict scarce resources management and monitoring?',
#     'Who is in Charge of ict scarce resources management and monitoring?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=154 for more information']},
#   {'tag': 'ict standards and quality of service',
#    'patterns': ['Guide me to ict standards and quality of service?',
#     'Where do you get ict standards and quality of service?',
#     'What is the link to the ict standards and quality of service?',
#     'How do you get ict standards and quality of service?',
#     'Who is in Charge of ict standards and quality of service?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=155 for more information']},
#   {'tag': 'postal  courier services regulation and e commerce development',
#    'patterns': ['Guide me to postal  courier services regulation and e commerce development?',
#     'Where do you get postal  courier services regulation and e commerce development?',
#     'What is the link to the postal  courier services regulation and e commerce development?',
#     'How do you get postal  courier services regulation and e commerce development?',
#     'Who is in Charge of postal  courier services regulation and e commerce development?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=253 for more information']},
#   {'tag': 'ict media regulation',
#    'patterns': ['Guide me to ict media regulation?',
#     'Where do you get ict media regulation?',
#     'What is the link to the ict media regulation?',
#     'How do you get ict media regulation?',
#     'Who is in Charge of ict media regulation?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=156 for more information']},
#   {'tag': 'regulatory instruments',
#    'patterns': ['Guide me to regulatory instruments?',
#     'Where do you get regulatory instruments?',
#     'What is the link to the regulatory instruments?',
#     'How do you get regulatory instruments?',
#     'Who is in Charge of regulatory instruments?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=160 for more information']},
#   {'tag': 'laws and orders',
#    'patterns': ['Guide me to laws and orders?',
#     'Where do you get laws and orders?',
#     'What is the link to the laws and orders?',
#     'How do you get laws and orders?',
#     'Who is in Charge of laws and orders?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=50 for more information']},
#   {'tag': 'regulations and guidelines',
#    'patterns': ['Guide me to regulations and guidelines?',
#     'Where do you get regulations and guidelines?',
#     'What is the link to the regulations and guidelines?',
#     'How do you get regulations and guidelines?',
#     'Who is in Charge of regulations and guidelines?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=51 for more information']},
#   {'tag': 'board decisions',
#    'patterns': ['Guide me to board decisions?',
#     'Where do you get board decisions?',
#     'What is the link to the board decisions?',
#     'How do you get board decisions?',
#     'Who is in Charge of board decisions?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=161 for more information']},
#   {'tag': 'other documents',
#    'patterns': ['Guide me to other documents?',
#     'Where do you get other documents?',
#     'What is the link to the other documents?',
#     'How do you get other documents?',
#     'Who is in Charge of other documents?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=232 for more information']},
#   {'tag': 'statistics',
#    'patterns': ['Guide me to statistics?',
#     'Where do you get statistics?',
#     'What is the link to the statistics?',
#     'How do you get statistics?',
#     'Who is in Charge of statistics?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=60 for more information']},
#   {'tag': 'monthly publication',
#    'patterns': ['Guide me to monthly publication?',
#     'Where do you get monthly publication?',
#     'What is the link to the monthly publication?',
#     'How do you get monthly publication?',
#     'Who is in Charge of monthly publication?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=188 for more information']},
#   {'tag': 'quarterly publication',
#    'patterns': ['Guide me to quarterly publication?',
#     'Where do you get quarterly publication?',
#     'What is the link to the quarterly publication?',
#     'How do you get quarterly publication?',
#     'Who is in Charge of quarterly publication?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=194 for more information']},
#   {'tag': 'sector reports',
#    'patterns': ['Guide me to sector reports?',
#     'Where do you get sector reports?',
#     'What is the link to the sector reports?',
#     'How do you get sector reports?',
#     'Who is in Charge of sector reports?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=164 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=222 for more information']},
#   {'tag': 'radiation protection',
#    'patterns': ['Guide me to radiation protection?',
#     'Where do you get radiation protection?',
#     'What is the link to the radiation protection?',
#     'How do you get radiation protection?',
#     'Who is in Charge of radiation protection?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=237 for more information']},
#   {'tag': 'overview',
#    'patterns': ['Guide me to overview?',
#     'Where do you get overview?',
#     'What is the link to the overview?',
#     'How do you get overview?',
#     'Who is in Charge of overview?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=238 for more information']},
#   {'tag': 'services',
#    'patterns': ['Guide me to services?',
#     'Where do you get services?',
#     'What is the link to the services?',
#     'How do you get services?',
#     'Who is in Charge of services?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=251 for more information']},
#   {'tag': 'law governing radiation protection',
#    'patterns': ['Guide me to law governing radiation protection?',
#     'Where do you get law governing radiation protection?',
#     'What is the link to the law governing radiation protection?',
#     'How do you get law governing radiation protection?',
#     'Who is in Charge of law governing radiation protection?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=284 for more information']},
#   {'tag': 'regulations and guidelines',
#    'patterns': ['Guide me to regulations and guidelines?',
#     'Where do you get regulations and guidelines?',
#     'What is the link to the regulations and guidelines?',
#     'How do you get regulations and guidelines?',
#     'Who is in Charge of regulations and guidelines?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=282 for more information']},
#   {'tag': 'sector publications',
#    'patterns': ['Guide me to sector publications?',
#     'Where do you get sector publications?',
#     'What is the link to the sector publications?',
#     'How do you get sector publications?',
#     'Who is in Charge of sector publications?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=283 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=286 for more information']},
#   {'tag': 'energy',
#    'patterns': ['Guide me to energy?',
#     'Where do you get energy?',
#     'What is the link to the energy?',
#     'How do you get energy?',
#     'Who is in Charge of energy?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=63 for more information']},
#   {'tag': 'overview',
#    'patterns': ['Guide me to overview?',
#     'Where do you get overview?',
#     'What is the link to the overview?',
#     'How do you get overview?',
#     'Who is in Charge of overview?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=137 for more information']},
#   {'tag': 'sub sectors and services',
#    'patterns': ['Guide me to sub sectors and services?',
#     'Where do you get sub sectors and services?',
#     'What is the link to the sub sectors and services?',
#     'How do you get sub sectors and services?',
#     'Who is in Charge of sub sectors and services?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=173 for more information']},
#   {'tag': 'electricity',
#    'patterns': ['Guide me to electricity?',
#     'Where do you get electricity?',
#     'What is the link to the electricity?',
#     'How do you get electricity?',
#     'Who is in Charge of electricity?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=65 for more information']},
#   {'tag': 'renewable energy',
#    'patterns': ['Guide me to renewable energy?',
#     'Where do you get renewable energy?',
#     'What is the link to the renewable energy?',
#     'How do you get renewable energy?',
#     'Who is in Charge of renewable energy?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=67 for more information']},
#   {'tag': 'downstream petroleum',
#    'patterns': ['Guide me to downstream petroleum?',
#     'Where do you get downstream petroleum?',
#     'What is the link to the downstream petroleum?',
#     'How do you get downstream petroleum?',
#     'Who is in Charge of downstream petroleum?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=66 for more information']},
#   {'tag': 'gas',
#    'patterns': ['Guide me to gas?',
#     'Where do you get gas?',
#     'What is the link to the gas?',
#     'How do you get gas?',
#     'Who is in Charge of gas?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=64 for more information']},
#   {'tag': 'regulatory instruments',
#    'patterns': ['Guide me to regulatory instruments?',
#     'Where do you get regulatory instruments?',
#     'What is the link to the regulatory instruments?',
#     'How do you get regulatory instruments?',
#     'Who is in Charge of regulatory instruments?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=174 for more information']},
#   {'tag': 'laws and orders',
#    'patterns': ['Guide me to laws and orders?',
#     'Where do you get laws and orders?',
#     'What is the link to the laws and orders?',
#     'How do you get laws and orders?',
#     'Who is in Charge of laws and orders?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=68 for more information']},
#   {'tag': 'regulations and guidelines',
#    'patterns': ['Guide me to regulations and guidelines?',
#     'Where do you get regulations and guidelines?',
#     'What is the link to the regulations and guidelines?',
#     'How do you get regulations and guidelines?',
#     'Who is in Charge of regulations and guidelines?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=98 for more information']},
#   {'tag': 'board decisions',
#    'patterns': ['Guide me to board decisions?',
#     'Where do you get board decisions?',
#     'What is the link to the board decisions?',
#     'How do you get board decisions?',
#     'Who is in Charge of board decisions?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=70 for more information']},
#   {'tag': 'draft regulations and guidelines',
#    'patterns': ['Guide me to draft regulations and guidelines?',
#     'Where do you get draft regulations and guidelines?',
#     'What is the link to the draft regulations and guidelines?',
#     'How do you get draft regulations and guidelines?',
#     'Who is in Charge of draft regulations and guidelines?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=235 for more information']},
#   {'tag': 'sector reports',
#    'patterns': ['Guide me to sector reports?',
#     'Where do you get sector reports?',
#     'What is the link to the sector reports?',
#     'How do you get sector reports?',
#     'Who is in Charge of sector reports?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=176 for more information']},
#   {'tag': 'statistics',
#    'patterns': ['Guide me to statistics?',
#     'Where do you get statistics?',
#     'What is the link to the statistics?',
#     'How do you get statistics?',
#     'Who is in Charge of statistics?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=71 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=223 for more information']},
#   {'tag': 'water   sanitation',
#    'patterns': ['Guide me to water   sanitation?',
#     'Where do you get water   sanitation?',
#     'What is the link to the water   sanitation?',
#     'How do you get water   sanitation?',
#     'Who is in Charge of water   sanitation?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=62 for more information']},
#   {'tag': 'overview',
#    'patterns': ['Guide me to overview?',
#     'Where do you get overview?',
#     'What is the link to the overview?',
#     'How do you get overview?',
#     'Who is in Charge of overview?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=153 for more information']},
#   {'tag': 'sub sectors and services',
#    'patterns': ['Guide me to sub sectors and services?',
#     'Where do you get sub sectors and services?',
#     'What is the link to the sub sectors and services?',
#     'How do you get sub sectors and services?',
#     'Who is in Charge of sub sectors and services?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=165 for more information']},
#   {'tag': 'water',
#    'patterns': ['Guide me to water?',
#     'Where do you get water?',
#     'What is the link to the water?',
#     'How do you get water?',
#     'Who is in Charge of water?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=74 for more information']},
#   {'tag': 'sanitation',
#    'patterns': ['Guide me to sanitation?',
#     'Where do you get sanitation?',
#     'What is the link to the sanitation?',
#     'How do you get sanitation?',
#     'Who is in Charge of sanitation?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=75 for more information']},
#   {'tag': 'regulatory instruments',
#    'patterns': ['Guide me to regulatory instruments?',
#     'Where do you get regulatory instruments?',
#     'What is the link to the regulatory instruments?',
#     'How do you get regulatory instruments?',
#     'Who is in Charge of regulatory instruments?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=169 for more information']},
#   {'tag': 'laws and orders',
#    'patterns': ['Guide me to laws and orders?',
#     'Where do you get laws and orders?',
#     'What is the link to the laws and orders?',
#     'How do you get laws and orders?',
#     'Who is in Charge of laws and orders?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=76 for more information']},
#   {'tag': 'regulations and guidelines',
#    'patterns': ['Guide me to regulations and guidelines?',
#     'Where do you get regulations and guidelines?',
#     'What is the link to the regulations and guidelines?',
#     'How do you get regulations and guidelines?',
#     'Who is in Charge of regulations and guidelines?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=167 for more information']},
#   {'tag': 'board decisions',
#    'patterns': ['Guide me to board decisions?',
#     'Where do you get board decisions?',
#     'What is the link to the board decisions?',
#     'How do you get board decisions?',
#     'Who is in Charge of board decisions?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=77 for more information']},
#   {'tag': 'draft regulations and guidelines',
#    'patterns': ['Guide me to draft regulations and guidelines?',
#     'Where do you get draft regulations and guidelines?',
#     'What is the link to the draft regulations and guidelines?',
#     'How do you get draft regulations and guidelines?',
#     'Who is in Charge of draft regulations and guidelines?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=231 for more information']},
#   {'tag': 'statistics',
#    'patterns': ['Guide me to statistics?',
#     'Where do you get statistics?',
#     'What is the link to the statistics?',
#     'How do you get statistics?',
#     'Who is in Charge of statistics?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=78 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=224 for more information']},
#   {'tag': 'transport',
#    'patterns': ['Guide me to transport?',
#     'Where do you get transport?',
#     'What is the link to the transport?',
#     'How do you get transport?',
#     'Who is in Charge of transport?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=89 for more information']},
#   {'tag': 'overview',
#    'patterns': ['Guide me to overview?',
#     'Where do you get overview?',
#     'What is the link to the overview?',
#     'How do you get overview?',
#     'Who is in Charge of overview?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=89 for more information']},
#   {'tag': 'sub sectors and services',
#    'patterns': ['Guide me to sub sectors and services?',
#     'Where do you get sub sectors and services?',
#     'What is the link to the sub sectors and services?',
#     'How do you get sub sectors and services?',
#     'Who is in Charge of sub sectors and services?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=178 for more information']},
#   {'tag': 'road transport',
#    'patterns': ['Guide me to road transport?',
#     'Where do you get road transport?',
#     'What is the link to the road transport?',
#     'How do you get road transport?',
#     'Who is in Charge of road transport?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=81 for more information']},
#   {'tag': 'freight forwarders service',
#    'patterns': ['Guide me to freight forwarders service?',
#     'Where do you get freight forwarders service?',
#     'What is the link to the freight forwarders service?',
#     'How do you get freight forwarders service?',
#     'Who is in Charge of freight forwarders service?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=234 for more information']},
#   {'tag': 'waterways transport',
#    'patterns': ['Guide me to waterways transport?',
#     'Where do you get waterways transport?',
#     'What is the link to the waterways transport?',
#     'How do you get waterways transport?',
#     'Who is in Charge of waterways transport?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=82 for more information']},
#   {'tag': 'regulatory instruments',
#    'patterns': ['Guide me to regulatory instruments?',
#     'Where do you get regulatory instruments?',
#     'What is the link to the regulatory instruments?',
#     'How do you get regulatory instruments?',
#     'Who is in Charge of regulatory instruments?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=179 for more information']},
#   {'tag': 'laws and orders',
#    'patterns': ['Guide me to laws and orders?',
#     'Where do you get laws and orders?',
#     'What is the link to the laws and orders?',
#     'How do you get laws and orders?',
#     'Who is in Charge of laws and orders?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=84 for more information']},
#   {'tag': 'regulations and guidelines',
#    'patterns': ['Guide me to regulations and guidelines?',
#     'Where do you get regulations and guidelines?',
#     'What is the link to the regulations and guidelines?',
#     'How do you get regulations and guidelines?',
#     'Who is in Charge of regulations and guidelines?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=85 for more information']},
#   {'tag': 'board decisions',
#    'patterns': ['Guide me to board decisions?',
#     'Where do you get board decisions?',
#     'What is the link to the board decisions?',
#     'How do you get board decisions?',
#     'Who is in Charge of board decisions?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=181 for more information']},
#   {'tag': 'sector  reports',
#    'patterns': ['Guide me to sector  reports?',
#     'Where do you get sector  reports?',
#     'What is the link to the sector  reports?',
#     'How do you get sector  reports?',
#     'Who is in Charge of sector  reports?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=185 for more information']},
#   {'tag': 'statistics',
#    'patterns': ['Guide me to statistics?',
#     'Where do you get statistics?',
#     'What is the link to the statistics?',
#     'How do you get statistics?',
#     'Who is in Charge of statistics?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=86 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=88 for more information']},
#   {'tag': 'online services',
#    'patterns': ['Guide me to online services?',
#     'Where do you get online services?',
#     'What is the link to the online services?',
#     'How do you get online services?',
#     'Who is in Charge of online services?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=269 for more information']},
#   {'tag': 'all online services',
#    'patterns': ['Guide me to all online services?',
#     'Where do you get all online services?',
#     'What is the link to the all online services?',
#     'How do you get all online services?',
#     'Who is in Charge of all online services?'],
#    'responses': ['You can use this link https://licensing.rura.rw/ for more information']},
#   {'tag': 'media center',
#    'patterns': ['Guide me to media center?',
#     'Where do you get media center?',
#     'What is the link to the media center?',
#     'How do you get media center?',
#     'Who is in Charge of media center?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=17 for more information']},
#   {'tag': 'news',
#    'patterns': ['Guide me to news?',
#     'Where do you get news?',
#     'What is the link to the news?',
#     'How do you get news?',
#     'Who is in Charge of news?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=38 for more information']},
#   {'tag': 'upcoming events',
#    'patterns': ['Guide me to upcoming events?',
#     'Where do you get upcoming events?',
#     'What is the link to the upcoming events?',
#     'How do you get upcoming events?',
#     'Who is in Charge of upcoming events?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=37 for more information']},
#   {'tag': 'press release',
#    'patterns': ['Guide me to press release?',
#     'Where do you get press release?',
#     'What is the link to the press release?',
#     'How do you get press release?',
#     'Who is in Charge of press release?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=34 for more information']},
#   {'tag': 'jobs',
#    'patterns': ['Guide me to jobs?',
#     'Where do you get jobs?',
#     'What is the link to the jobs?',
#     'How do you get jobs?',
#     'Who is in Charge of jobs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=33 for more information']},
#   {'tag': 'announcements',
#    'patterns': ['Guide me to announcements?',
#     'Where do you get announcements?',
#     'What is the link to the announcements?',
#     'How do you get announcements?',
#     'Who is in Charge of announcements?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=187 for more information']},
#   {'tag': 'the regulator magazine',
#    'patterns': ['Guide me to the regulator magazine?',
#     'Where do you get the regulator magazine?',
#     'What is the link to the the regulator magazine?',
#     'How do you get the regulator magazine?',
#     'Who is in Charge of the regulator magazine?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=8 for more information']},
#   {'tag': 'public notices',
#    'patterns': ['Guide me to public notices?',
#     'Where do you get public notices?',
#     'What is the link to the public notices?',
#     'How do you get public notices?',
#     'Who is in Charge of public notices?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=227 for more information']},
#   {'tag': 'reports',
#    'patterns': ['Guide me to reports?',
#     'Where do you get reports?',
#     'What is the link to the reports?',
#     'How do you get reports?',
#     'Who is in Charge of reports?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=29 for more information']},
#   {'tag': 'tenders',
#    'patterns': ['Guide me to tenders?',
#     'Where do you get tenders?',
#     'What is the link to the tenders?',
#     'How do you get tenders?',
#     'Who is in Charge of tenders?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=133 for more information']},
#   {'tag': 'contact us',
#    'patterns': ['Guide me to contact us?',
#     'Where do you get contact us?',
#     'What is the link to the contact us?',
#     'How do you get contact us?',
#     'Who is in Charge of contact us?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=4 for more information']},
#   {'tag': 'ict sector',
#    'patterns': ['Guide me to ict sector?',
#     'Where do you get ict sector?',
#     'What is the link to the ict sector?',
#     'How do you get ict sector?',
#     'Who is in Charge of ict sector?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=104&tx_news_pi1%5Bnews%5D=5&tx_news_pi1%5Bcontroller%5D=News&tx_news_pi1%5Baction%5D=detail&cHash=39b2a753d27b615aed7a70e896c563dd for more information']},
#   {'tag': 'read more',
#    'patterns': ['Guide me to read more?',
#     'Where do you get read more?',
#     'What is the link to the read more?',
#     'How do you get read more?',
#     'Who is in Charge of read more?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=104&tx_news_pi1%5Bnews%5D=5&tx_news_pi1%5Bcontroller%5D=News&tx_news_pi1%5Baction%5D=detail&cHash=39b2a753d27b615aed7a70e896c563dd for more information']},
#   {'tag': 'transport sector',
#    'patterns': ['Guide me to transport sector?',
#     'Where do you get transport sector?',
#     'What is the link to the transport sector?',
#     'How do you get transport sector?',
#     'Who is in Charge of transport sector?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=104&tx_news_pi1%5Bnews%5D=9&tx_news_pi1%5Bcontroller%5D=News&tx_news_pi1%5Baction%5D=detail&cHash=1e306f11763554a3c2ec733ce42b81a8 for more information']},
#   {'tag': 'read more',
#    'patterns': ['Guide me to read more?',
#     'Where do you get read more?',
#     'What is the link to the read more?',
#     'How do you get read more?',
#     'Who is in Charge of read more?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=104&tx_news_pi1%5Bnews%5D=9&tx_news_pi1%5Bcontroller%5D=News&tx_news_pi1%5Baction%5D=detail&cHash=1e306f11763554a3c2ec733ce42b81a8 for more information']},
#   {'tag': 'water and sanitation sector',
#    'patterns': ['Guide me to water and sanitation sector?',
#     'Where do you get water and sanitation sector?',
#     'What is the link to the water and sanitation sector?',
#     'How do you get water and sanitation sector?',
#     'Who is in Charge of water and sanitation sector?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=104&tx_news_pi1%5Bnews%5D=10&tx_news_pi1%5Bcontroller%5D=News&tx_news_pi1%5Baction%5D=detail&cHash=080d8ba93034ea8804a270818390fcc7 for more information']},
#   {'tag': 'read more',
#    'patterns': ['Guide me to read more?',
#     'Where do you get read more?',
#     'What is the link to the read more?',
#     'How do you get read more?',
#     'Who is in Charge of read more?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=104&tx_news_pi1%5Bnews%5D=10&tx_news_pi1%5Bcontroller%5D=News&tx_news_pi1%5Baction%5D=detail&cHash=080d8ba93034ea8804a270818390fcc7 for more information']},
#   {'tag': 'energy sector',
#    'patterns': ['Guide me to energy sector?',
#     'Where do you get energy sector?',
#     'What is the link to the energy sector?',
#     'How do you get energy sector?',
#     'Who is in Charge of energy sector?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=104&tx_news_pi1%5Bnews%5D=8&tx_news_pi1%5Bcontroller%5D=News&tx_news_pi1%5Baction%5D=detail&cHash=be96bf6a3f57cce32b1c5a95937656dd for more information']},
#   {'tag': 'read more',
#    'patterns': ['Guide me to read more?',
#     'Where do you get read more?',
#     'What is the link to the read more?',
#     'How do you get read more?',
#     'Who is in Charge of read more?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=104&tx_news_pi1%5Bnews%5D=8&tx_news_pi1%5Bcontroller%5D=News&tx_news_pi1%5Baction%5D=detail&cHash=be96bf6a3f57cce32b1c5a95937656dd for more information']},
#   {'tag': 'radiation protection ',
#    'patterns': ['Guide me to radiation protection ?',
#     'Where do you get radiation protection ?',
#     'What is the link to the radiation protection ?',
#     'How do you get radiation protection ?',
#     'Who is in Charge of radiation protection ?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=104&tx_news_pi1%5Bnews%5D=7&tx_news_pi1%5Bcontroller%5D=News&tx_news_pi1%5Baction%5D=detail&cHash=16f185b66db7e293156282257bf28fb4 for more information']},
#   {'tag': 'read more',
#    'patterns': ['Guide me to read more?',
#     'Where do you get read more?',
#     'What is the link to the read more?',
#     'How do you get read more?',
#     'Who is in Charge of read more?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=104&tx_news_pi1%5Bnews%5D=7&tx_news_pi1%5Bcontroller%5D=News&tx_news_pi1%5Baction%5D=detail&cHash=16f185b66db7e293156282257bf28fb4 for more information']},
#   {'tag': 'online services',
#    'patterns': ['Guide me to online services?',
#     'Where do you get online services?',
#     'What is the link to the online services?',
#     'How do you get online services?',
#     'Who is in Charge of online services?'],
#    'responses': ['You can use this link https://licensing.rura.rw/ for more information']},
#   {'tag': 'driver vocational card  dvc ',
#    'patterns': ['Guide me to driver vocational card  dvc ?',
#     'Where do you get driver vocational card  dvc ?',
#     'What is the link to the driver vocational card  dvc ?',
#     'How do you get driver vocational card  dvc ?',
#     'Who is in Charge of driver vocational card  dvc ?'],
#    'responses': ['You can use this link https://dvc.rura.rw/ for more information']},
#   {'tag': 'consumer complaint',
#    'patterns': ['Guide me to consumer complaint?',
#     'Where do you get consumer complaint?',
#     'What is the link to the consumer complaint?',
#     'How do you get consumer complaint?',
#     'Who is in Charge of consumer complaint?'],
#    'responses': ['You can use this link https://licensing.rura.rw/customer/complaint/form for more information']},
#   {'tag': 'type approved devices',
#    'patterns': ['Guide me to type approved devices?',
#     'Where do you get type approved devices?',
#     'What is the link to the type approved devices?',
#     'How do you get type approved devices?',
#     'Who is in Charge of type approved devices?'],
#    'responses': ['You can use this link https://licensing.rura.rw/type-approval/search-devices for more information']},
#   {'tag': 'imei verification system',
#    'patterns': ['Guide me to imei verification system?',
#     'Where do you get imei verification system?',
#     'What is the link to the imei verification system?',
#     'How do you get imei verification system?',
#     'Who is in Charge of imei verification system?'],
#    'responses': ['You can use this link http://www.rura.rw/tcrplus/ for more information']},
#   {'tag': 'annual reports',
#    'patterns': ['Guide me to annual reports?',
#     'Where do you get annual reports?',
#     'What is the link to the annual reports?',
#     'How do you get annual reports?',
#     'Who is in Charge of annual reports?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=213 for more information']},
#   {'tag': 'tariffs',
#    'patterns': ['Guide me to tariffs?',
#     'Where do you get tariffs?',
#     'What is the link to the tariffs?',
#     'How do you get tariffs?',
#     'Who is in Charge of tariffs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=288 for more information']},
#   {'tag': 'statistics',
#    'patterns': ['Guide me to statistics?',
#     'Where do you get statistics?',
#     'What is the link to the statistics?',
#     'How do you get statistics?',
#     'Who is in Charge of statistics?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=276 for more information']},
#   {'tag': 'revoked licenses',
#    'patterns': ['Guide me to revoked licenses?',
#     'Where do you get revoked licenses?',
#     'What is the link to the revoked licenses?',
#     'How do you get revoked licenses?',
#     'Who is in Charge of revoked licenses?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=287 for more information']},
#   {'tag': 'key ict documents',
#    'patterns': ['Guide me to key ict documents?',
#     'Where do you get key ict documents?',
#     'What is the link to the key ict documents?',
#     'How do you get key ict documents?',
#     'Who is in Charge of key ict documents?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=211 for more information']},
#   {'tag': 'consumer affairs',
#    'patterns': ['Guide me to consumer affairs?',
#     'Where do you get consumer affairs?',
#     'What is the link to the consumer affairs?',
#     'How do you get consumer affairs?',
#     'Who is in Charge of consumer affairs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=279 for more information']},
#   {'tag': 'regulations and guidelines',
#    'patterns': ['Guide me to regulations and guidelines?',
#     'Where do you get regulations and guidelines?',
#     'What is the link to the regulations and guidelines?',
#     'How do you get regulations and guidelines?',
#     'Who is in Charge of regulations and guidelines?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=207 for more information']},
#   {'tag': 'board decisions',
#    'patterns': ['Guide me to board decisions?',
#     'Where do you get board decisions?',
#     'What is the link to the board decisions?',
#     'How do you get board decisions?',
#     'Who is in Charge of board decisions?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=208 for more information']},
#   {'tag': 'regulations for consultation',
#    'patterns': ['Guide me to regulations for consultation?',
#     'Where do you get regulations for consultation?',
#     'What is the link to the regulations for consultation?',
#     'How do you get regulations for consultation?',
#     'Who is in Charge of regulations for consultation?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=291 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=217 for more information']},
#   {'tag': 'tweets by rura_rwanda',
#    'patterns': ['Guide me to tweets by rura_rwanda?',
#     'Where do you get tweets by rura_rwanda?',
#     'What is the link to the tweets by rura_rwanda?',
#     'How do you get tweets by rura_rwanda?',
#     'Who is in Charge of tweets by rura_rwanda?'],
#    'responses': ['You can use this link https://twitter.com/RURA_RWANDA for more information']},
#   {'tag': '\r\n          rura hosts government institutions to discuss nuclear safeguards implementation\r\n        ',
#    'patterns': ['Guide me to \r\n          rura hosts government institutions to discuss nuclear safeguards implementation\r\n        ?',
#     'Where do you get \r\n          rura hosts government institutions to discuss nuclear safeguards implementation\r\n        ?',
#     'What is the link to the \r\n          rura hosts government institutions to discuss nuclear safeguards implementation\r\n        ?',
#     'How do you get \r\n          rura hosts government institutions to discuss nuclear safeguards implementation\r\n        ?',
#     'Who is in Charge of \r\n          rura hosts government institutions to discuss nuclear safeguards implementation\r\n        ?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=95&tx_news_pi1%5Bnews%5D=1697&tx_news_pi1%5Bday%5D=22&tx_news_pi1%5Bmonth%5D=11&tx_news_pi1%5Byear%5D=2022&cHash=3114a7391a8b2521275ed7a234870177 for more information']},
#   {'tag': '\r\n          an ai ethics primer for the rwandan ai ecosystem and consultation on ethical ai guidelines \r\n        ',
#    'patterns': ['Guide me to \r\n          an ai ethics primer for the rwandan ai ecosystem and consultation on ethical ai guidelines \r\n        ?',
#     'Where do you get \r\n          an ai ethics primer for the rwandan ai ecosystem and consultation on ethical ai guidelines \r\n        ?',
#     'What is the link to the \r\n          an ai ethics primer for the rwandan ai ecosystem and consultation on ethical ai guidelines \r\n        ?',
#     'How do you get \r\n          an ai ethics primer for the rwandan ai ecosystem and consultation on ethical ai guidelines \r\n        ?',
#     'Who is in Charge of \r\n          an ai ethics primer for the rwandan ai ecosystem and consultation on ethical ai guidelines \r\n        ?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=95&tx_news_pi1%5Bnews%5D=1696&tx_news_pi1%5Bday%5D=21&tx_news_pi1%5Bmonth%5D=11&tx_news_pi1%5Byear%5D=2022&cHash=2bcaf2dbcf178d2fed28fb08b3183058 for more information']},
#   {'tag': '\r\n          rura in partnership with iaea hosts a regional workshop on radiation protection officers and qualified experts\r\n        ',
#    'patterns': ['Guide me to \r\n          rura in partnership with iaea hosts a regional workshop on radiation protection officers and qualified experts\r\n        ?',
#     'Where do you get \r\n          rura in partnership with iaea hosts a regional workshop on radiation protection officers and qualified experts\r\n        ?',
# ...
#     'How do you get \r\n          rura in partnership with iaea hosts a regional workshop on radiation protection officers and qualified experts\r\n        ?',
#     'Who is in Charge of \r\n          rura in partnership with iaea hosts a regional workshop on radiation protection officers and qualified experts\r\n        ?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=95&tx_news_pi1%5Bnews%5D=1691&tx_news_pi1%5Bday%5D=7&tx_news_pi1%5Bmonth%5D=11&tx_news_pi1%5Byear%5D=2022&cHash=b7e6c9903dbdaefe8f39ab8a03ff9a88 for more information']},
#   {'tag': '\r\n          rura and zambian energy regulator exchange experience on lpg regulation\r\n        ',
#    'patterns': ['Guide me to \r\n          rura and zambian energy regulator exchange experience on lpg regulation\r\n        ?',
#     'Where do you get \r\n          rura and zambian energy regulator exchange experience on lpg regulation\r\n        ?',
#     'What is the link to the \r\n          rura and zambian energy regulator exchange experience on lpg regulation\r\n        ?',
#     'How do you get \r\n          rura and zambian energy regulator exchange experience on lpg regulation\r\n        ?',
#     'Who is in Charge of \r\n          rura and zambian energy regulator exchange experience on lpg regulation\r\n        ?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=95&tx_news_pi1%5Bnews%5D=1671&tx_news_pi1%5Bday%5D=23&tx_news_pi1%5Bmonth%5D=9&tx_news_pi1%5Byear%5D=2022&cHash=e0cbb1a8937231f8afa48064e0215e3e for more information']},
#   {'tag': '\r\n          open call for the rwandan artificial intelligence ai  ecosystem  ai ethics applied programme and consultation\r\n        ',
#    'patterns': ['Guide me to \r\n          open call for the rwandan artificial intelligence ai  ecosystem  ai ethics applied programme and consultation\r\n        ?',
#     'Where do you get \r\n          open call for the rwandan artificial intelligence ai  ecosystem  ai ethics applied programme and consultation\r\n        ?',
#     'What is the link to the \r\n          open call for the rwandan artificial intelligence ai  ecosystem  ai ethics applied programme and consultation\r\n        ?',
#     'How do you get \r\n          open call for the rwandan artificial intelligence ai  ecosystem  ai ethics applied programme and consultation\r\n        ?',
#     'Who is in Charge of \r\n          open call for the rwandan artificial intelligence ai  ecosystem  ai ethics applied programme and consultation\r\n        ?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=95&tx_news_pi1%5Bnews%5D=1653&tx_news_pi1%5Bday%5D=22&tx_news_pi1%5Bmonth%5D=8&tx_news_pi1%5Byear%5D=2022&cHash=cd34289aa0182cdb2eb51a976bb05208 for more information']},
#   {'tag': 'public notices',
#    'patterns': ['Guide me to public notices?',
#     'Where do you get public notices?',
#     'What is the link to the public notices?',
#     'How do you get public notices?',
#     'Who is in Charge of public notices?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=227 for more information']},
#   {'tag': 'announcements',
#    'patterns': ['Guide me to announcements?',
#     'Where do you get announcements?',
#     'What is the link to the announcements?',
#     'How do you get announcements?',
#     'Who is in Charge of announcements?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=187 for more information']},
#   {'tag': 'jobs',
#    'patterns': ['Guide me to jobs?',
#     'Where do you get jobs?',
#     'What is the link to the jobs?',
#     'How do you get jobs?',
#     'Who is in Charge of jobs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=33 for more information']},
#   {'tag': 'e recruitment',
#    'patterns': ['Guide me to e recruitment?',
#     'Where do you get e recruitment?',
#     'What is the link to the e recruitment?',
#     'How do you get e recruitment?',
#     'Who is in Charge of e recruitment?'],
#    'responses': ['You can use this link https://rura.rw/recruitment/index.php for more information']},
#   {'tag': 'e internship ',
#    'patterns': ['Guide me to e internship ?',
#     'Where do you get e internship ?',
#     'What is the link to the e internship ?',
#     'How do you get e internship ?',
#     'Who is in Charge of e internship ?'],
#    'responses': ['You can use this link https://rura.rw/internship/ for more information']},
#   {'tag': 'rwanda trade portal',
#    'patterns': ['Guide me to rwanda trade portal?',
#     'Where do you get rwanda trade portal?',
#     'What is the link to the rwanda trade portal?',
#     'How do you get rwanda trade portal?',
#     'Who is in Charge of rwanda trade portal?'],
#    'responses': ['You can use this link https://rwandatrade.rw/ for more information']},
#   {'tag': 'background',
#    'patterns': ['Guide me to background?',
#     'Where do you get background?',
#     'What is the link to the background?',
#     'How do you get background?',
#     'Who is in Charge of background?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=44 for more information']},
#   {'tag': 'rura functions',
#    'patterns': ['Guide me to rura functions?',
#     'Where do you get rura functions?',
#     'What is the link to the rura functions?',
#     'How do you get rura functions?',
#     'Who is in Charge of rura functions?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=45 for more information']},
#   {'tag': 'rura mission  vision and values',
#    'patterns': ['Guide me to rura mission  vision and values?',
#     'Where do you get rura mission  vision and values?',
#     'What is the link to the rura mission  vision and values?',
#     'How do you get rura mission  vision and values?',
#     'Who is in Charge of rura mission  vision and values?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=46 for more information']},
#   {'tag': 'rura law and related orders',
#    'patterns': ['Guide me to rura law and related orders?',
#     'Where do you get rura law and related orders?',
#     'What is the link to the rura law and related orders?',
#     'How do you get rura law and related orders?',
#     'Who is in Charge of rura law and related orders?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=202 for more information']},
#   {'tag': 'regional and international partnerships',
#    'patterns': ['Guide me to regional and international partnerships?',
#     'Where do you get regional and international partnerships?',
#     'What is the link to the regional and international partnerships?',
#     'How do you get regional and international partnerships?',
#     'Who is in Charge of regional and international partnerships?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=47 for more information']},
#   {'tag': 'consumer affairs',
#    'patterns': ['Guide me to consumer affairs?',
#     'Where do you get consumer affairs?',
#     'What is the link to the consumer affairs?',
#     'How do you get consumer affairs?',
#     'Who is in Charge of consumer affairs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=262 for more information']},
#   {'tag': 'strategic plan 2022 2027',
#    'patterns': ['Guide me to strategic plan 2022 2027?',
#     'Where do you get strategic plan 2022 2027?',
#     'What is the link to the strategic plan 2022 2027?',
#     'How do you get strategic plan 2022 2027?',
#     'Who is in Charge of strategic plan 2022 2027?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=289 for more information']},
#   {'tag': 'service charter',
#    'patterns': ['Guide me to service charter?',
#     'Where do you get service charter?',
#     'What is the link to the service charter?',
#     'How do you get service charter?',
#     'Who is in Charge of service charter?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=150 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=103 for more information']},
#   {'tag': 'overview',
#    'patterns': ['Guide me to overview?',
#     'Where do you get overview?',
#     'What is the link to the overview?',
#     'How do you get overview?',
#     'Who is in Charge of overview?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=49 for more information']},
#   {'tag': 'sub sectors and services',
#    'patterns': ['Guide me to sub sectors and services?',
#     'Where do you get sub sectors and services?',
#     'What is the link to the sub sectors and services?',
#     'How do you get sub sectors and services?',
#     'Who is in Charge of sub sectors and services?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=159 for more information']},
#   {'tag': 'regulatory instruments',
#    'patterns': ['Guide me to regulatory instruments?',
#     'Where do you get regulatory instruments?',
#     'What is the link to the regulatory instruments?',
#     'How do you get regulatory instruments?',
#     'Who is in Charge of regulatory instruments?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=160 for more information']},
#   {'tag': 'statistics',
#    'patterns': ['Guide me to statistics?',
#     'Where do you get statistics?',
#     'What is the link to the statistics?',
#     'How do you get statistics?',
#     'Who is in Charge of statistics?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=60 for more information']},
#   {'tag': 'sector reports',
#    'patterns': ['Guide me to sector reports?',
#     'Where do you get sector reports?',
#     'What is the link to the sector reports?',
#     'How do you get sector reports?',
#     'Who is in Charge of sector reports?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=164 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=222 for more information']},
#   {'tag': 'overview',
#    'patterns': ['Guide me to overview?',
#     'Where do you get overview?',
#     'What is the link to the overview?',
#     'How do you get overview?',
#     'Who is in Charge of overview?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=137 for more information']},
#   {'tag': 'sub sectors and services',
#    'patterns': ['Guide me to sub sectors and services?',
#     'Where do you get sub sectors and services?',
#     'What is the link to the sub sectors and services?',
#     'How do you get sub sectors and services?',
#     'Who is in Charge of sub sectors and services?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=173 for more information']},
#   {'tag': 'regulatory instruments',
#    'patterns': ['Guide me to regulatory instruments?',
#     'Where do you get regulatory instruments?',
#     'What is the link to the regulatory instruments?',
#     'How do you get regulatory instruments?',
#     'Who is in Charge of regulatory instruments?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=174 for more information']},
#   {'tag': 'statistics',
#    'patterns': ['Guide me to statistics?',
#     'Where do you get statistics?',
#     'What is the link to the statistics?',
#     'How do you get statistics?',
#     'Who is in Charge of statistics?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=71 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=223 for more information']},
#   {'tag': 'overview',
#    'patterns': ['Guide me to overview?',
#     'Where do you get overview?',
#     'What is the link to the overview?',
#     'How do you get overview?',
#     'Who is in Charge of overview?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=153 for more information']},
#   {'tag': 'sub sectors and services',
#    'patterns': ['Guide me to sub sectors and services?',
#     'Where do you get sub sectors and services?',
#     'What is the link to the sub sectors and services?',
#     'How do you get sub sectors and services?',
#     'Who is in Charge of sub sectors and services?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=165 for more information']},
#   {'tag': 'regulatory instruments',
#    'patterns': ['Guide me to regulatory instruments?',
#     'Where do you get regulatory instruments?',
#     'What is the link to the regulatory instruments?',
#     'How do you get regulatory instruments?',
#     'Who is in Charge of regulatory instruments?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=169 for more information']},
#   {'tag': 'statistics',
#    'patterns': ['Guide me to statistics?',
#     'Where do you get statistics?',
#     'What is the link to the statistics?',
#     'How do you get statistics?',
#     'Who is in Charge of statistics?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=78 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=224 for more information']},
#   {'tag': 'overview',
#    'patterns': ['Guide me to overview?',
#     'Where do you get overview?',
#     'What is the link to the overview?',
#     'How do you get overview?',
#     'Who is in Charge of overview?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=89 for more information']},
#   {'tag': 'sub sectors and services',
#    'patterns': ['Guide me to sub sectors and services?',
#     'Where do you get sub sectors and services?',
#     'What is the link to the sub sectors and services?',
#     'How do you get sub sectors and services?',
#     'Who is in Charge of sub sectors and services?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=178 for more information']},
#   {'tag': 'regulatory instruments',
#    'patterns': ['Guide me to regulatory instruments?',
#     'Where do you get regulatory instruments?',
#     'What is the link to the regulatory instruments?',
#     'How do you get regulatory instruments?',
#     'Who is in Charge of regulatory instruments?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=179 for more information']},
#   {'tag': 'sector  reports',
#    'patterns': ['Guide me to sector  reports?',
#     'Where do you get sector  reports?',
#     'What is the link to the sector  reports?',
#     'How do you get sector  reports?',
#     'Who is in Charge of sector  reports?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=185 for more information']},
#   {'tag': 'statistics',
#    'patterns': ['Guide me to statistics?',
#     'Where do you get statistics?',
#     'What is the link to the statistics?',
#     'How do you get statistics?',
#     'Who is in Charge of statistics?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=86 for more information']},
#   {'tag': 'faqs',
#    'patterns': ['Guide me to faqs?',
#     'Where do you get faqs?',
#     'What is the link to the faqs?',
#     'How do you get faqs?',
#     'Who is in Charge of faqs?'],
#    'responses': ['You can use this link https://rura.rw/index.php?id=88 for more information']},
#   {'tag': 'all online services',
#    'patterns': ['Guide me to all online services?',
#     'Where do you get all online services?',
#     'What is the link to the all online services?',
#     'How do you get all online services?',
#     'Who is in Charge of all online services?'],
#    'responses': ['You can use this link https://licensing.rura.rw/ for more information']}]}

# %%
# !git clone https://github.com/agent87/pytorch-chatbot.git
# Out:
# Cloning into 'pytorch-chatbot'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 44 (delta 12), reused 8 (delta 8), pack-reused 23
# Unpacking objects: 100% (44/44), done.

# %%
import json

with open('/content/pytorch-chatbot/intents.json', 'w+') as intent_file:
  intent_file.seek(0)
  intent_file.truncate()
  json.dump(file, intent_file)

# %%
# %cd pytorch-chatbot/
# Out:
# /content/pytorch-chatbot

# %%
import nltk 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Train the Chatbot to associate the patterns/questions to an intent

# %%
# !python train.py
# Out:
# 825 patterns
# 89 tags: ['\r\n          an ai ethics primer for the rwandan ai ecosystem and consultation on ethical ai guidelines \r\n        ', '\r\n          open call for the rwandan artificial intelligence ai  ecosystem  ai ethics applied programme and consultation\r\n        ', '\r\n          rura and zambian energy regulator exchange experience on lpg regulation\r\n        ', '\r\n          rura hosts government institutions to discuss nuclear safeguards implementation\r\n        ', '\r\n          rura in partnership with iaea hosts a regional workshop on radiation protection officers and qualified experts\r\n        ', 'about rura', 'all online services', 'announcements', 'annual reports', 'background', 'board decisions', 'business plan to buy an apartment building', 'complaints handling procedures', 'consumer affairs', 'consumer awareness and educational tools', 'consumer complaint', 'consumer rights and obligations', 'contact us', 'downstream petroleum', 'draft regulations and guidelines', 'driver vocational card  dvc ', 'e internship ', 'e recruitment', 'electricity', 'energy', 'energy sector', 'faqs', 'freight forwarders service', 'gas', 'home', 'ict', 'ict media regulation', 'ict scarce resources management and monitoring', 'ict sector', 'ict standards and quality of service', 'imei verification system', 'jobs', 'key ict documents', 'law governing radiation protection', 'laws and orders', 'laws and regulations', 'media center', 'monthly publication', 'news', 'online services', 'other documents', 'overview', 'postal  courier services regulation and e commerce development', 'press release', 'public notices', 'quarterly publication', 'radiation protection', 'radiation protection ', 'read more', 'regional and international partnerships', 'regulations and guidelines', 'regulations for consultation', 'regulatory instruments', 'renewable energy', 'reports', 'revoked licenses', 'road transport', 'rura functions', 'rura law and related orders', 'rura mission  vision and values', 'rwanda trade portal', 'sanitation', 'sector  reports', 'sector publications', 'sector reports', 'service charter', 'services', 'statement of admission', 'statistics', 'strategic plan 2022 2027', 'sub sectors and services', 'tariffs', 'tenders', 'the regulator magazine', 'transport', 'transport sector', 'tweets by rura_rwanda', 'type approved devices', 'upcoming events', 'water', 'water   sanitation', 'water and sanitation sector', 'waterways transport', 'writing a good abstract for research paper']
# 177 unique stemmed words: ['2022', '2027', 'a', 'about', 'abstract', 'admiss', 'affair', 'ai', 'all', 'an', 'and', 'announc', 'annual', 'apart', 'appli', 'approv', 'artifici', 'awar', 'background', 'board', 'build', 'busi', 'buy', 'by', 'call', 'card', 'center', 'charg', 'charter', 'commerc', 'complaint', 'consult', 'consum', 'contact', 'courier', 'decis', 'develop', 'devic', 'discuss', 'do', 'document', 'downstream', 'draft', 'driver', 'dvc', 'e', 'ecosystem', 'educ', 'electr', 'energi', 'ethic', 'event', 'exchang', 'experi', 'expert', 'faq', 'for', 'forward', 'freight', 'function', 'ga', 'get', 'good', 'govern', 'guid', 'guidelin', 'handl', 'home', 'host', 'how', 'iaea', 'ict', 'imei', 'implement', 'in', 'institut', 'instrument', 'intellig', 'intern', 'internship', 'is', 'job', 'key', 'law', 'licens', 'link', 'lpg', 'magazin', 'manag', 'me', 'media', 'mission', 'monitor', 'monthli', 'more', 'news', 'notic', 'nuclear', 'oblig', 'of', 'offic', 'on', 'onlin', 'open', 'order', 'other', 'overview', 'paper', 'partnership', 'petroleum', 'plan', 'portal', 'postal', 'press', 'primer', 'procedur', 'programm', 'protect', 'public', 'qualifi', 'qualiti', 'quarterli', 'radiat', 'read', 'recruit', 'region', 'regul', 'regulatori', 'relat', 'releas', 'renew', 'report', 'research', 'resourc', 'revok', 'right', 'road', 'rura', 'rura_rwanda', 'rwanda', 'rwandan', 'safeguard', 'sanit', 'scarc', 'sector', 'servic', 'standard', 'statement', 'statist', 'strateg', 'sub', 'system', 'tariff', 'tender', 'the', 'to', 'tool', 'trade', 'transport', 'tweet', 'type', 'upcom', 'us', 'valu', 'verif', 'vision', 'vocat', 'water', 'waterway', 'what', 'where', 'who', 'with', 'workshop', 'write', 'you', 'zambian']
# 177 89
# Epoch [100/1000], Loss: 0.0000
# Epoch [200/1000], Loss: 0.0000
# Epoch [300/1000], Loss: 0.0000
# Epoch [400/1000], Loss: 0.0000
# Epoch [500/1000], Loss: 0.0000
# Epoch [600/1000], Loss: 0.0000
# Epoch [700/1000], Loss: 0.9169
# Epoch [800/1000], Loss: 0.0000
# Epoch [900/1000], Loss: 0.0000
# Epoch [1000/1000], Loss: 0.0000
# final loss: 0.0000
# training complete. file saved to data.pth

# %%
# !python chat.py

# %%
import random
import json

import torch

from model import NeuralNet
from nltk_utils import bag_of_words, tokenize

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

with open('intents.json', 'r') as json_data:
    intents = json.load(json_data)

FILE = "data.pth"
data = torch.load(FILE)

input_size = data["input_size"]
hidden_size = data["hidden_size"]
output_size = data["output_size"]
all_words = data['all_words']
tags = data['tags']
model_state = data["model_state"]

model = NeuralNet(input_size, hidden_size, output_size).to(device)
model.load_state_dict(model_state)
model.eval()

bot_name = "Patrice"
print("Let's chat! (type 'quit' to exit)")

def query(question : str):
  # sentence = "do you use credit cards?"
  sentence = question

  sentence = tokenize(sentence)
  X = bag_of_words(sentence, all_words)
  X = X.reshape(1, X.shape[0])
  X = torch.from_numpy(X).to(device)

  output = model(X)
  _, predicted = torch.max(output, dim=1)

  tag = tags[predicted.item()]

  probs = torch.softmax(output, dim=1)
  prob = probs[0][predicted.item()]
  if prob.item() > 0.75:
      for intent in intents['intents']:
          if tag == intent["tag"]:
              return f"{bot_name}: {random.choice(intent['responses'])}"
  else:
      return f"{bot_name}: I do not understand..."
# Out:
# Let's chat! (type 'quit' to exit)

# %%
response = query('guide me to about rura?')

# %%
response
# Out:
# 'Sam: You can use this link https://rura.rw/index.php?id=25 for more information'

# %%
# !pip install langdetect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 8.1 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from langdetect) (1.15.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=1f5f30589df271a9ca8638895d07ada4fdf6018078fb6882af889e0855a472c9
#   Stored in directory: /root/.cache/pip/wheels/13/c7/b0/79f66658626032e78fc1a83103690ef6797d551cb22e56e734
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
import requests
import json


class translator:
    api_url = "https://translate.googleapis.com/translate_a/single"
    client = "?client=gtx&dt=t"
    dt = "&dt=t"

    #fROM English to Kinyarwanda
    def translate(text : str , target_lang : str, source_lang : str):
        sl = f"&sl={source_lang}"
        tl = f"&tl={target_lang}"
        r = requests.get(translator.api_url+ translator.client + translator.dt + sl + tl + "&q=" + text)
        return json.loads(r.text)[0][0][0]

# %%
resp = translator.translate(text='Mpereza amakuru yerekeye Belise', target_lang='fr', source_lang='rw')

# %%
resp
# Out:
# 'Je recherche des informations sur Belize'

# %%
from langdetect import detect

def process_question(text : str):

  source_lang = detect(text)
  resp = translator.translate(text=text, target_lang='en', source_lang=source_lang)
  return resp, source_lang

def process_answer(text : str, source_lang):
  resp = translator.translate(text=text, target_lang=source_lang, source_lang='en')
  return resp

# %%
def process(QUESTION: str):
  USER_QUERY, SL = process_question(QUESTION) #Translate the original question into english and store the source lang
  RESPONSE = query(USER_QUERY) #Asking th chatbot question
  ORIGINAL_RESPONSE = process_answer(RESPONSE, SL)
  return ORIGINAL_RESPONSE

process("Donne mois de l'information sur RURA?")
# Out:
# "Patrice : Vous pouvez utiliser ce lien https://rura.rw/index.php?id=25 pour plus d'informations"

# %% [markdown]
# # Fast API

# %%
# !pip install fastapi pyngrok uvicorn nest-asyncio

# %%
# !ngrok authtoken 1VG7hGOGCl7R9CJANekYvuY3ZZA_5QGcuAoAPW4FUF9jW1LHY
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
from fastapi import FastAPI, Request
from fastapi.responses import HTMLResponse

# %%
app = FastAPI(title='Chatbot')

# %%
@app.get('/')
def index():
  return 'Welcome to my Web app'


@app.get('/chatbot')
def chatbot(query : str = None):
  return process(query)

# %%
import nest_asyncio
from pyngrok import ngrok
import uvicorn

ngrok_tunnel = ngrok.connect(8000)
print('Please use the following link to access you app', ngrok_tunnel.public_url)

nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# Please use the following link to access you app http://38f6-35-247-75-70.ngrok.io
# INFO:     Started server process [71]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     2c0f:eb68:203:3c00:8cda:533f:2bc7:e908:0 - "GET / HTTP/1.1" 200 OK
# INFO:     2c0f:eb68:203:3c00:8cda:533f:2bc7:e908:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     154.0.29.5:0 - "GET / HTTP/1.1" 200 OK

# %%
# !pkill ngrok
